# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset from Excel
file_path = 'diab_dataset.xlsx'
df = pd.read_excel(file_path)

# Display the first few rows of the dataset
# print("First few rows of the dataset:")
# print(df.head())

# Summary statistics
# print("\nSummary statistics of the dataset:")
print(df.describe())
# # Remove rows with null values in 'HDL' and 'Sys BP' columns
# df = df.dropna(subset=['HDL', 'Sys BP'])

# Check for missing values
# print("\nMissing values in the dataset:")
# print(df.isnull().sum())

# num_rows, num_columns = df.shape

# Print the number of rows
# print(f"Number of rows in the dataset: {num_rows}")

from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=l.fit_transform(df[i])


# df.head()


# df['Diabetes duration (y)'] = df['Diabetes duration (y)'].fillna(df['Diabetes duration (y)'].mean())
# df['Height(cm)'] = df['Height(cm)'].fillna(df['Height(cm)'].mean())
# df['BMI (kg/m2)'] = df['BMI (kg/m2)'].fillna(df['BMI (kg/m2)'].mean())
# df['HbA1c (%)'] = df['HbA1c (%)'].fillna(df['HbA1c (%)'].mean())
# df['FBG (mmol/L)'] = df['FBG (mmol/L)'].fillna(df['FBG (mmol/L)'].mean())
# df['TG（mmoll）'] = df['TG（mmoll）'].fillna(df['TG（mmoll）'].mean())
# df['C-peptide (ng/ml）'] = df['C-peptide (ng/ml）'].fillna(df['C-peptide (ng/ml）'].mean())
# df['TC（mmoll）'] = df['TC（mmoll）'].fillna(df['TC（mmoll）'].mean())
# df['HDLC（mmoll）'] = df['HDLC（mmoll）'].fillna(df['HDLC（mmoll）'].mean())
# df['LDLC（mmoll）'] = df['LDLC（mmoll）'].fillna(df['LDLC（mmoll）'].mean())

# df.to_csv('Diabetic_Nephropathy.csv')

x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# df.BMI = df.BMI.fillna(df.BMI.mean())
# df.HDL = df.HDL.fillna(df.HDL.mean())
# df.Sys_BP = df.Sys_BP.fillna(df.Sys_BP.mean())
# df.OGTT = df.OGTT.fillna(df.OGTT.mean())

# df.to_csv('Gestational_mean.csv')
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_normalized = scaler.fit_transform(x)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_normalized,y,test_size=0.3,random_state=0)
# print(y_test)



# from sklearn.tree import DecisionTreeRegressor
# dtr=DecisionTreeRegressor(random_state=0)
# dtr.fit(x_train,y_train)

# #predicting the value

# y_pred=dtr.predict(x_test)
# # from sklearn.metrics import accuracy_score
# # accuracy = accuracy_score(y_test, y_pred)
# # print(f"Accuracy: {accuracy}")

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Decision Tree Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))






# Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels


# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# import seaborn as sns
# import matplotlib.pyplot as plt
# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
#             xticklabels=le.classes_, 
#             yticklabels=le.classes_)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# # plt.show()


# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming 'dtr' is a classifier, and 'x_test' and 'y_test' are your test data
# y_pred = dtr.predict(x_test)
# y_pred_classes = np.argmax(y_pred, axis=0)  # Assuming one-hot encoding for class labels
# y_test_classes = np.argmax(y_test, axis=0)  # Assuming one-hot encoding for class labels

# cm = confusion_matrix(y_test_classes, y_pred_classes)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.show()





# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)


# from sklearn.svm import SVR
# svr=SVR()
# svr.fit(x_train,y_train)

# #predicting the value

# y_pred=svr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for SVM Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))




# print(y_test)
# print("=========================")
# print(y_pred)
# from sklearn.metrics import accuracy_score

# # Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")
# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# #y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(x_train,y_train)

# #predicting the value

# y_pred=lr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Linear Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))

# from sklearn.metrics import mean_absolute_error

# # Assuming 'y_true' is the true target values and 'y_pred' is the predicted target values
# mae = mean_absolute_error(y_test, y_pred)
# print(f"Mean Absolute Error: {mae}")






# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(x_train,y_train)

# #predicting the value

# y_pred=svc.predict(x_test)
# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy of svc: {accuracy}")

#_______________________________________________________________________________________________________________________

# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# # Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# # If not, replace them with your actual data

# # Create a Random Forest classifier
# rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# # Train the Random Forest model
# rf_classifier.fit(x_train, y_train)

# # Make predictions on the test set
# y_pred_rf = rf_classifier.predict(x_test)

# # Evaluate the Random Forest model
# accuracy_rf = accuracy_score(y_test, y_pred_rf)
# # conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
# # class_report_rf = classification_report(y_test, y_pred_rf)

# # Display the results
# print(f"Random Forest Model Accuracy: {accuracy_rf}")
# # # print("Random Forest Confusion Matrix:")
# # # print(conf_matrix_rf)
# # # print("Random Forest Classification Report:")
# # # print(class_report_rf)



# from sklearn.neighbors import KNeighborsClassifier
# knn = KNeighborsClassifier(n_neighbors=100)
# knn.fit(x_train,y_train)

# #predicting the value

# y_pred=knn.predict(x_test)

# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy of KNN: {accuracy}")








# accuracy = accuracy_score(y_test, y_pred)


# conf_matrix = confusion_matrix(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)
# --------------------------------------------------------------------------HYPER______________________________________

# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score

# # Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# # If not, replace them with your actual data

# # Create a Random Forest classifier
# rf_classifier = RandomForestClassifier(random_state=42)

# # Define the hyperparameter grid
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [10, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }

# # Create the GridSearchCV object
# grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)

# # Fit the grid search to the data
# grid_search.fit(x_train, y_train)

# # Get the best hyperparameters
# best_params = grid_search.best_params_

# # Create a Random Forest classifier with the best hyperparameters
# best_rf_classifier = RandomForestClassifier(random_state=42, **best_params)

# # Train the Random Forest model with the best hyperparameters
# best_rf_classifier.fit(x_train, y_train)

# # Make predictions on the test set
# y_pred_rf = best_rf_classifier.predict(x_test)

# # Evaluate the Random Forest model with the best hyperparameters
# accuracy_rf = accuracy_score(y_test, y_pred_rf)

# # Print the best hyperparameters
# print("Best Hyperparameters:", best_params)
# print("Accuracy with Best Hyperparameters:", accuracy_rf)

#?////////////////////////////////////////////////////////////////////////
# import pickle
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# Load the dataset from Excel
# file_path = 'Diabetic_Nephropathy.csv'
# df = pd.read_csv(file_path)

# Display the first few rows of the dataset
# print("First few rows of the dataset:")
# print(df.head())

# # Summary statistics
# print("\nSummary statistics of the dataset:")
# print(df.describe())
# # Remove rows with null values in 'HDL' and 'Sys BP' columns
# df = df.dropna(subset=['HDL', 'Sys BP'])

# Check for missing values
# print("\nMissing values in the dataset:")
# print(df.isnull().sum())

# num_rows, num_columns = df.shape

# Print the number of rows
# print(f"Number of rows in the dataset: {num_rows}")

# from sklearn.preprocessing import LabelEncoder
# l=LabelEncoder()
# for i in df.columns:
#     if df[i].dtype == 'object':
#         df[i]=l.fit_transform(df[i])


# df.head()


# df['Diabetes duration (y)'] = df['Diabetes duration (y)'].fillna(df['Diabetes duration (y)'].mean())
# df['Height(cm)'] = df['Height(cm)'].fillna(df['Height(cm)'].mean())
# df['BMI (kg/m2)'] = df['BMI (kg/m2)'].fillna(df['BMI (kg/m2)'].mean())
# df['HbA1c (%)'] = df['HbA1c (%)'].fillna(df['HbA1c (%)'].mean())
# df['FBG (mmol/L)'] = df['FBG (mmol/L)'].fillna(df['FBG (mmol/L)'].mean())
# df['TG（mmoll）'] = df['TG（mmoll）'].fillna(df['TG（mmoll）'].mean())
# df['C-peptide (ng/ml）'] = df['C-peptide (ng/ml）'].fillna(df['C-peptide (ng/ml）'].mean())
# df['TC（mmoll）'] = df['TC（mmoll）'].fillna(df['TC（mmoll）'].mean())
# df['HDLC（mmoll）'] = df['HDLC（mmoll）'].fillna(df['HDLC（mmoll）'].mean())
# df['LDLC（mmoll）'] = df['LDLC（mmoll）'].fillna(df['LDLC（mmoll）'].mean())

# df.to_csv('Diabetic_Nephropathy.csv')

# x=df.iloc[:,:-1].values
# y=df.iloc[:,-1].values

# df.BMI = df.BMI.fillna(df.BMI.mean())
# df.HDL = df.HDL.fillna(df.HDL.mean())
# df.Sys_BP = df.Sys_BP.fillna(df.Sys_BP.mean())
# df.OGTT = df.OGTT.fillna(df.OGTT.mean())

# df.to_csv('Gestational_mean.csv')
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_normalized = scaler.fit_transform(x)

# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(X_normalized,y,test_size=0.3,random_state=0)
# print(y_test)



# from sklearn.tree import DecisionTreeRegressor
# dtr=DecisionTreeRegressor(random_state=0)
# dtr.fit(x_train,y_train)

# #predicting the value

# y_pred=dtr.predict(x_test)
# # from sklearn.metrics import accuracy_score
# # accuracy = accuracy_score(y_test, y_pred)
# # print(f"Accuracy: {accuracy}")

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Decision Tree Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))






# Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels


# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# import seaborn as sns
# import matplotlib.pyplot as plt
# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
#             xticklabels=le.classes_, 
#             yticklabels=le.classes_)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# # plt.show()


# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming 'dtr' is a classifier, and 'x_test' and 'y_test' are your test data
# y_pred = dtr.predict(x_test)
# y_pred_classes = np.argmax(y_pred, axis=0)  # Assuming one-hot encoding for class labels
# y_test_classes = np.argmax(y_test, axis=0)  # Assuming one-hot encoding for class labels

# cm = confusion_matrix(y_test_classes, y_pred_classes)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.show()





# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)


# from sklearn.svm import SVR
# svr=SVR()
# svr.fit(x_train,y_train)

# #predicting the value

# y_pred=svr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for SVM Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))




# print(y_test)
# print("=========================")
# print(y_pred)
# from sklearn.metrics import accuracy_score

# # Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")
# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# #y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(x_train,y_train)

# #predicting the value

# y_pred=lr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Linear Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))

# from sklearn.metrics import mean_absolute_error

# # Assuming 'y_true' is the true target values and 'y_pred' is the predicted target values
# mae = mean_absolute_error(y_test, y_pred)
# print(f"Mean Absolute Error: {mae}")






# from sklearn.svm import SVC
# svc=SVC()
# svc.fit(x_train,y_train)

# #predicting the value

# y_pred=svc.predict(x_test)
# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy of svc: {accuracy}")

#_______________________________________________________________________________________________________________________




from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# If not, replace them with your actual data

# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the Random Forest model
rf_classifier.fit(x_train, y_train)

# Make predictions on the test set
y_pred_rf = rf_classifier.predict(x_test)

# Evaluate the Random Forest model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
# conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
# class_report_rf = classification_report(y_test, y_pred_rf)


# -----------------------------------------------------------------AUC-ROC Score---------------------------------------------
from sklearn.metrics import accuracy_score, roc_auc_score
y_pred_probs_rf = rf_classifier.predict_proba(x_test)
auc_roc_score_rf = roc_auc_score(y_test, y_pred_probs_rf[:, 1])
print(f"Random Forest AUC-ROC Score: {auc_roc_score_rf}")

from sklearn.metrics import confusion_matrix, classification_report

# ... (your existing code) ...

# Make predictions on the test set
y_pred_rf = rf_classifier.predict(x_test)

# Evaluate the Random Forest model
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
print("Confusion Matrix:")
print(conf_matrix_rf)

# Calculate specificity and sensitivity
TN, FP, FN, TP = conf_matrix_rf.ravel()

specificity = TN / (TN + FP)
sensitivity = TP / (TP + FN)

print(f"Specificity: {specificity}")
print(f"Sensitivity: {sensitivity}")

# Print classification report for additional metrics
class_report_rf = classification_report(y_test, y_pred_rf)
print("Classification Report:")
print(class_report_rf)

from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# ... (your existing code) ...

# Make predictions on the test set
y_pred_probs_rf = rf_classifier.predict_proba(x_test)[:, 1]

# Compute ROC curve and ROC area for each class
fpr, tpr, _ = roc_curve(y_test, y_pred_probs_rf)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()





# ---------------------------------------------------------------------------------------------------------------------------
# Display the results
print(f"Random Forest Model Accuracy: {accuracy_rf}")
# # print("Random Forest Confusion Matrix:")
# # print(conf_matrix_rf)
# # print("Random Forest Classification Report:")
# # print(class_report_rf)



# from sklearn.neighbors import KNeighborsClassifier
# knn = KNeighborsClassifier(n_neighbors=100)
# knn.fit(x_train,y_train)

# #predicting the value

# y_pred=knn.predict(x_test)

# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy of KNN: {accuracy}")








# accuracy = accuracy_score(y_test, y_pred)


# conf_matrix = confusion_matrix(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)
# --------------------------------------------------------------------------HYPER______________________________________

# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score

# # Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# # If not, replace them with your actual data

# # Create a Random Forest classifier
# rf_classifier = RandomForestClassifier(random_state=42)

# # Define the hyperparameter grid
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [10, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }

# # Create the GridSearchCV object
# grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)

# # Fit the grid search to the data
# grid_search.fit(x_train, y_train)

# # Get the best hyperparameters
# best_params = grid_search.best_params_

# # Create a Random Forest classifier with the best hyperparameters
# best_rf_classifier = RandomForestClassifier(random_state=42, **best_params)

# # Train the Random Forest model with the best hyperparameters
# best_rf_classifier.fit(x_train, y_train)

# # Make predictions on the test set
# y_pred_rf = best_rf_classifier.predict(x_test)

# # Evaluate the Random Forest model with the best hyperparameters
# accuracy_rf = accuracy_score(y_test, y_pred_rf)

# # Print the best hyperparameters
# print("Best Hyperparameters:", best_params)
# print("Accuracy with Best Hyperparameters:", accuracy_rf)

#?////////////////////////////////////////////////////////////////////////
import pickle
pickle_out = open("Diabetes.pkl","wb")
pickle.dump(rf_classifier, pickle_out)
pickle_out.close()

# import numpy as np
# rf_classifier.predict([[2,3,4,1]])

# import numpy as np
# rf_classifier.predict([[2,3,4,1]])
# Out:
#                Age          BMI          FPG         FFPG          SBP  \
# count  4303.000000  4303.000000  4303.000000  4303.000000  4303.000000
# mean     48.085057    24.123923     5.226368     5.729084   123.219382
# std      14.686155     3.397294     0.781089     1.424568    17.513858
# min      22.000000    15.600000     1.780000     3.200000    72.000000
# 25%      35.000000    21.700000     4.700000     4.900000   111.000000
# 50%      46.000000    24.000000     5.140000     5.300000   122.000000
# 75%      59.000000    26.300000     5.700000     6.020000   134.000000
# max      93.000000    45.800000     6.990000    29.700000   200.000000
#
#                DBP  family_histroy      smoking     drinking          ALT  \
# count  4303.000000     4303.000000  4303.000000  4303.000000  4303.000000
# mean     76.360446        0.061585     3.006123     3.209935    26.754810
# std      11.004056        0.240428     1.199571     0.939842    22.279922
# ...
