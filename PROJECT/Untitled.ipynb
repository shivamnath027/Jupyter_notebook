# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset from Excel
file_path = 'Diabetic_Nephropathy.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
# print("First few rows of the dataset:")
# print(df.head())

# Summary statistics
print("\nSummary statistics of the dataset:")
print(df.describe())
# # Remove rows with null values in 'HDL' and 'Sys BP' columns
# df = df.dropna(subset=['HDL', 'Sys BP'])

# Check for missing values
# print("\nMissing values in the dataset:")
# print(df.isnull().sum())

# num_rows, num_columns = df.shape

# Print the number of rows
# print(f"Number of rows in the dataset: {num_rows}")

from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=l.fit_transform(df[i])


# df.head()


# df['Diabetes duration (y)'] = df['Diabetes duration (y)'].fillna(df['Diabetes duration (y)'].mean())
# df['Height(cm)'] = df['Height(cm)'].fillna(df['Height(cm)'].mean())
# df['BMI (kg/m2)'] = df['BMI (kg/m2)'].fillna(df['BMI (kg/m2)'].mean())
# df['HbA1c (%)'] = df['HbA1c (%)'].fillna(df['HbA1c (%)'].mean())
# df['FBG (mmol/L)'] = df['FBG (mmol/L)'].fillna(df['FBG (mmol/L)'].mean())
# df['TG（mmoll）'] = df['TG（mmoll）'].fillna(df['TG（mmoll）'].mean())
# df['C-peptide (ng/ml）'] = df['C-peptide (ng/ml）'].fillna(df['C-peptide (ng/ml）'].mean())
# df['TC（mmoll）'] = df['TC（mmoll）'].fillna(df['TC（mmoll）'].mean())
# df['HDLC（mmoll）'] = df['HDLC（mmoll）'].fillna(df['HDLC（mmoll）'].mean())
# df['LDLC（mmoll）'] = df['LDLC（mmoll）'].fillna(df['LDLC（mmoll）'].mean())

# df.to_csv('Diabetic_Nephropathy.csv')

x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# df.BMI = df.BMI.fillna(df.BMI.mean())
# df.HDL = df.HDL.fillna(df.HDL.mean())
# df.Sys_BP = df.Sys_BP.fillna(df.Sys_BP.mean())
# df.OGTT = df.OGTT.fillna(df.OGTT.mean())

# df.to_csv('Gestational_mean.csv')
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_normalized = scaler.fit_transform(x)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_normalized,y,test_size=0.3,random_state=0)
# print(y_test)



# from sklearn.tree import DecisionTreeRegressor
# dtr=DecisionTreeRegressor(random_state=0)
# dtr.fit(x_train,y_train)

# #predicting the value

# y_pred=dtr.predict(x_test)
# # from sklearn.metrics import accuracy_score
# # accuracy = accuracy_score(y_test, y_pred)
# # print(f"Accuracy: {accuracy}")

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Decision Tree Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))






# Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels


# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# import seaborn as sns
# import matplotlib.pyplot as plt
# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
#             xticklabels=le.classes_, 
#             yticklabels=le.classes_)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# # plt.show()


# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming 'dtr' is a classifier, and 'x_test' and 'y_test' are your test data
# y_pred = dtr.predict(x_test)
# y_pred_classes = np.argmax(y_pred, axis=0)  # Assuming one-hot encoding for class labels
# y_test_classes = np.argmax(y_test, axis=0)  # Assuming one-hot encoding for class labels

# cm = confusion_matrix(y_test_classes, y_pred_classes)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.show()





# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)


# from sklearn.svm import SVR
# svr=SVR()
# svr.fit(x_train,y_train)

# #predicting the value

# y_pred=svr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for SVM Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))




# print(y_test)
# print("=========================")
# print(y_pred)
# from sklearn.metrics import accuracy_score

# # Assuming 'y_true' is the true class labels and 'y_pred' is the predicted class labels
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")
# from sklearn.metrics import confusion_matrix
# y_pred=dtr.predict(x_test) 
# y_pred=np.argmax(y_pred, axis=0)
# y_test=np.argmax(y_test, axis=0)
# #y_test=np.array([1])
# cm = confusion_matrix(y_test, y_pred)
# print(cm)

# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(x_train,y_train)

# #predicting the value

# y_pred=lr.predict(x_test)

# #evaluating the model

# from sklearn.metrics import r2_score,mean_squared_error
# print("Results for Linear Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(y_test,y_pred),r2_score(y_test,y_pred)))

# from sklearn.metrics import mean_absolute_error

# # Assuming 'y_true' is the true target values and 'y_pred' is the predicted target values
# mae = mean_absolute_error(y_test, y_pred)
# print(f"Mean Absolute Error: {mae}")






from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)

#predicting the value

y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of svc: {accuracy}")

#_______________________________________________________________________________________________________________________

# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# # Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# # If not, replace them with your actual data

# # Create a Random Forest classifier
# rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# # Train the Random Forest model
# rf_classifier.fit(x_train, y_train)

# # Make predictions on the test set
# y_pred_rf = rf_classifier.predict(x_test)

# # Evaluate the Random Forest model
# accuracy_rf = accuracy_score(y_test, y_pred_rf)
# # conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
# # class_report_rf = classification_report(y_test, y_pred_rf)

# # Display the results
# print(f"Random Forest Model Accuracy: {accuracy_rf}")
# # # print("Random Forest Confusion Matrix:")
# # # print(conf_matrix_rf)
# # # print("Random Forest Classification Report:")
# # # print(class_report_rf)



# from sklearn.neighbors import KNeighborsClassifier
# knn = KNeighborsClassifier(n_neighbors=100)
# knn.fit(x_train,y_train)

# #predicting the value

# y_pred=knn.predict(x_test)

# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy of KNN: {accuracy}")








# accuracy = accuracy_score(y_test, y_pred)


# conf_matrix = confusion_matrix(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)
# --------------------------------------------------------------------------HYPER______________________________________

# from sklearn.model_selection import GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score

# # Assuming 'x_train', 'x_test', 'y_train', and 'y_test' are your training and testing data
# # If not, replace them with your actual data

# # Create a Random Forest classifier
# rf_classifier = RandomForestClassifier(random_state=42)

# # Define the hyperparameter grid
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [10, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }

# # Create the GridSearchCV object
# grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=3, scoring='accuracy', n_jobs=-1)

# # Fit the grid search to the data
# grid_search.fit(x_train, y_train)

# # Get the best hyperparameters
# best_params = grid_search.best_params_

# # Create a Random Forest classifier with the best hyperparameters
# best_rf_classifier = RandomForestClassifier(random_state=42, **best_params)

# # Train the Random Forest model with the best hyperparameters
# best_rf_classifier.fit(x_train, y_train)

# # Make predictions on the test set
# y_pred_rf = best_rf_classifier.predict(x_test)

# # Evaluate the Random Forest model with the best hyperparameters
# accuracy_rf = accuracy_score(y_test, y_pred_rf)

# # Print the best hyperparameters
# print("Best Hyperparameters:", best_params)
# print("Accuracy with Best Hyperparameters:", accuracy_rf)

#?////////////////////////////////////////////////////////////////////////
import pickle
pickle_out = open("classifier.pkl","wb")
pickle.dump(rf_classifier, pickle_out)
pickle_out.close()

# import numpy as np
# rf_classifier.predict([[2,3,4,1]])
# Out:
# Summary statistics of the dataset:
#        Unnamed: 0         Sex         Age  Diabetes duration (y)  \
# count  767.000000  767.000000  767.000000             767.000000
# mean   383.000000    0.657106   56.080834               9.360248
# std    221.558119    0.474986   10.945807               7.005168
# min      0.000000    0.000000   24.000000               0.100000
# 25%    191.500000    0.000000   49.000000               3.000000
# 50%    383.000000    1.000000   56.000000               9.000000
# 75%    574.500000    1.000000   64.000000              14.000000
# max    766.000000    1.000000   88.000000              32.000000
#
#        Diabetic retinopathy (DR)     Smoking    Drinking  Height(cm)  \
# count                 767.000000  767.000000  767.000000  767.000000
# mean                    0.380704    0.316819    0.292047  166.714099
# std                     0.485877    0.465540    0.455000    8.479617
# min                     0.000000    0.000000    0.000000  108.000000
# 25%                     0.000000    0.000000    0.000000  160.000000
# 50%                     0.000000    0.000000    0.000000  168.000000
# 75%                     1.000000    1.000000    1.000000  173.000000
# max                     1.000000    1.000000    1.000000  190.000000
#
#        Weight(kg)  BMI (kg/m2)  ...  FBG (mmol/L)   TG（mmoll）  \
# count  767.000000   767.000000  ...    767.000000  767.000000
# mean    69.863038    25.075920  ...      8.472146    1.930354
# std     11.860997     3.558168  ...      3.009448    1.390183
# min     42.600000    16.384697  ...      1.024000    0.410000
# 25%     61.000000    22.859756  ...      6.270000    1.105000
# 50%     69.000000    24.801587  ...      7.840000    1.590000
# 75%     77.000000    26.971372  ...     10.145000    2.280000
# max    122.400000    63.443073  ...     22.090000   13.000000
#
#        C-peptide (ng/ml）   TC（mmoll）  HDLC（mmoll）  LDLC（mmoll）     Insulin  \
# count         767.000000  767.000000   767.000000   767.000000  767.000000
# mean            1.145548    4.426640     1.081237     2.885855    0.778357
# std             0.783239    1.030222     0.306034     7.000848    0.415623
# min             0.010000    0.710000     0.380000     0.370000    0.000000
# 25%             0.640000    3.715000     0.880000     2.015000    1.000000
# 50%             1.000000    4.360000     1.020000     2.580000    1.000000
# 75%             1.395000    4.995000     1.230000     3.200000    1.000000
# max             8.940000    8.740000     2.640000   195.000000    1.000000
#
#         Metformin  Lipid lowering drugs  Diabetic nephropathy (DN)
# count  767.000000            767.000000                 767.000000
# mean     0.644068              0.644068                   0.259452
# std      0.479107              0.479107                   0.438620
# min      0.000000              0.000000                   0.000000
# 25%      0.000000              0.000000                   0.000000
# 50%      1.000000              1.000000                   0.000000
# 75%      1.000000              1.000000                   1.000000
# max      1.000000              1.000000                   1.000000
#
# [8 rows x 23 columns]
# Best Hyperparameters: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy with Best Hyperparameters: 0.7142857142857143
